# %%
from ase.io import read, write
from ase.build import find_optimal_cell_shape, make_supercell
import numpy as np

# %%
file_loc = r"path/to/primitivecell.cif" #change file path
structure = read(file_loc)

# %%
structure.cell.array

# %%
structure.cell.cellpar()

# %%
transformation_matrix = find_optimal_cell_shape(structure.cell, 2, 'sc') #in-built ASE function to find transformation matrix resulting in supercell closest to a cube
supercell = make_supercell(structure,transformation_matrix)
output_loc = r"path/to/supercell"+str(i)+"_sc.cif"
write(output_loc, supercell)

# %%
supercell.cell.cellpar()

# %%
tm = np.array([[0,2,0],[-3,0,1],[2,-1,0]]) #Define specific transformation matrix based on oriented supercell transformation

# %%
nsc = make_supercell(structure,tm)

# %%
nsc.cell.cellpar()

# %%
output_loc = r"path/to/oriented/supercell.cif" #change file path
write(output_loc, nsc)
